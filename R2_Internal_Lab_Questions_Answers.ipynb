# %%
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## K-Nearest-Neighbors

# %% [markdown]
# KNN falls in the supervised learning family of algorithms. Informally, this means that we are given a labelled dataset consiting of training observations (x,y) and would like to capture the relationship between x and y. More formally, our goal is to learn a function h:X→Y so that given an unseen observation x, h(x) can confidently predict the corresponding output y.
#
# In this module we will explore the inner workings of KNN, choosing the optimal K values and using KNN from scikit-learn.

# %% [markdown]
# ## Overview
#
# 1.Read the problem statement.
#
# 2.Get the dataset.
#
# 3.Explore the dataset.
#
# 4.Pre-processing of dataset.
#
# 5.Visualization
#
# 6.Transform the dataset for building machine learning model.
#
# 7.Split data into train, test set.
#
# 7.Build Model.
#
# 8.Apply the model.
#
# 9.Evaluate the model.
#
# 10.Finding Optimal K value
#
# 11.Repeat 7,8,9 steps.

# %% [markdown]
# ## Problem statement
#
# ### Dataset
#
# The data set we’ll be using is the Iris Flower Dataset which was first introduced in 1936 by the famous statistician Ronald Fisher and consists of 50 observations from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals.
#
# **Attributes of the dataset:** https://archive.ics.uci.edu/ml/datasets/Iris
#
# **Train the KNN algorithm to be able to distinguish the species from one another given the measurements of the 4 features.**

# %% [markdown]
# ## Question 1
#
# Import the data set and print 10 random rows from the data set

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from scipy.stats import zscore
from sklearn.preprocessing import Imputer
from sklearn.metrics import accuracy_score
import seaborn as sns
import os
import seaborn as sns
from google.colab import files
uploaded = files.upload()
import os
# %matplotlib inline
# Out:
#      <input type="file" id="files-22129ce2-2270-482d-853d-98d7e9378ac5" name="files[]" multiple disabled />
#      <output id="result-22129ce2-2270-482d-853d-98d7e9378ac5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris.csv to iris (1).csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['iris.csv']))
a = np.random.randint(0,10,8)
a
# Out:
# array([3, 3, 5, 4, 2, 4, 2, 4])

# %%
df.sample(10)
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm          Species
# 133  134            6.3  ...           1.5   Iris-virginica
# 55    56            5.7  ...           1.3  Iris-versicolor
# 127  128            6.1  ...           1.8   Iris-virginica
# 64    65            5.6  ...           1.3  Iris-versicolor
# 134  135            6.1  ...           1.4   Iris-virginica
# 96    97            5.7  ...           1.3  Iris-versicolor
# 99   100            5.7  ...           1.3  Iris-versicolor
# 86    87            6.7  ...           1.5  Iris-versicolor
# 57    58            4.9  ...           1.0  Iris-versicolor
# 138  139            6.0  ...           1.8   Iris-virginica
#
# [10 rows x 6 columns]

# %% [markdown]
# ## Data Pre-processing

# %% [markdown]
# ## Question 2 - Estimating missing values
#
# *Its not good to remove the records having missing values all the time. We may end up loosing some data points. So, we will have to see how to replace those missing values with some estimated values (median) *

# %%
df.columns
# Out:
# Index([u'Id', u'SepalLengthCm', u'SepalWidthCm', u'PetalLengthCm',
#        u'PetalWidthCm', u'Species'],
#       dtype='object')

# %%
df.median()
# Out:
# Id               76.50
# SepalLengthCm     5.80
# SepalWidthCm      3.00
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64

# %%
df1 = df.fillna(df.median())
df1
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# 5      6            5.4  ...           0.4     Iris-setosa
# 6      7            4.6  ...           0.3     Iris-setosa
# 7      8            5.0  ...           0.2     Iris-setosa
# 8      9            4.4  ...           0.2     Iris-setosa
# 9     10            4.9  ...           0.1     Iris-setosa
# 10    11            5.4  ...           0.2     Iris-setosa
# 11    12            4.8  ...           0.2     Iris-setosa
# 12    13            4.8  ...           0.1     Iris-setosa
# 13    14            4.3  ...           0.1     Iris-setosa
# 14    15            5.8  ...           0.2     Iris-setosa
# 15    16            5.7  ...           0.4     Iris-setosa
# 16    17            5.4  ...           0.4     Iris-setosa
# 17    18            5.1  ...           0.3     Iris-setosa
# 18    19            5.7  ...           0.3     Iris-setosa
# 19    20            5.1  ...           0.3     Iris-setosa
# 20    21            5.4  ...           0.2     Iris-setosa
# 21    22            5.1  ...           0.4     Iris-setosa
# 22    23            4.6  ...           0.2     Iris-setosa
# 23    24            5.1  ...           0.5     Iris-setosa
# 24    25            4.8  ...           0.2     Iris-setosa
# 25    26            5.0  ...           0.2     Iris-setosa
# 26    27            5.0  ...           0.4     Iris-setosa
# 27    28            5.2  ...           0.2     Iris-setosa
# 28    29            5.2  ...           0.2     Iris-setosa
# 29    30            4.7  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 122  123            7.7  ...           2.0  Iris-virginica
# 123  124            6.3  ...           1.8  Iris-virginica
# 124  125            6.7  ...           2.1  Iris-virginica
# 125  126            7.2  ...           1.8  Iris-virginica
# 126  127            6.2  ...           1.8  Iris-virginica
# 127  128            6.1  ...           1.8  Iris-virginica
# 128  129            6.4  ...           2.1  Iris-virginica
# 129  130            7.2  ...           1.6  Iris-virginica
# 130  131            7.4  ...           1.9  Iris-virginica
# 131  132            7.9  ...           2.0  Iris-virginica
# 132  133            6.4  ...           2.2  Iris-virginica
# 133  134            6.3  ...           1.5  Iris-virginica
# 134  135            6.1  ...           1.4  Iris-virginica
# 135  136            7.7  ...           2.3  Iris-virginica
# 136  137            6.3  ...           2.4  Iris-virginica
# 137  138            6.4  ...           1.8  Iris-virginica
# 138  139            6.0  ...           1.8  Iris-virginica
# 139  140            6.9  ...           2.1  Iris-virginica
# 140  141            6.7  ...           2.4  Iris-virginica
# 141  142            6.9  ...           2.3  Iris-virginica
# 142  143            5.8  ...           1.9  Iris-virginica
# 143  144            6.8  ...           2.3  Iris-virginica
# 144  145            6.7  ...           2.5  Iris-virginica
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
# 150  151            5.9  ...           1.3  Iris-virginica
# 151  152            5.8  ...           1.8  Iris-virginica
#
# [152 rows x 6 columns]

# %% [markdown]
# ## Question 3 - Dealing with categorical data
#
# Change all the classes to numericals (0to2).

# %%
data ={'Iris-virginica':0,'Iris-setosa':1,'Iris-versicolor':2}

Iris = df1.replace({'Species': data})

Iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5           1.40           0.2        1
# 1      2            4.9           3.0           1.40           0.2        1
# 2      3            4.7           3.2           1.30           0.2        1
# 3      4            4.6           3.1           1.50           0.2        1
# 4      5            5.0           3.6           1.40           0.2        1
# 5      6            5.4           3.9           1.70           0.4        1
# 6      7            4.6           3.4           1.40           0.3        1
# 7      8            5.0           3.4           1.50           0.2        1
# 8      9            4.4           2.9           1.40           0.2        1
# 9     10            4.9           3.1           1.50           0.1        1
# 10    11            5.4           3.7           1.50           0.2        1
# 11    12            4.8           3.4           1.60           0.2        1
# 12    13            4.8           3.0           1.40           0.1        1
# 13    14            4.3           3.0           1.10           0.1        1
# 14    15            5.8           4.0           1.20           0.2        1
# 15    16            5.7           4.4           1.50           0.4        1
# 16    17            5.4           3.9           1.30           0.4        1
# 17    18            5.1           3.5           1.40           0.3        1
# 18    19            5.7           3.8           1.70           0.3        1
# 19    20            5.1           3.8           1.50           0.3        1
# 20    21            5.4           3.4           1.70           0.2        1
# 21    22            5.1           3.7           1.50           0.4        1
# 22    23            4.6           3.6           1.00           0.2        1
# 23    24            5.1           3.3           1.70           0.5        1
# 24    25            4.8           3.4           1.90           0.2        1
# 25    26            5.0           3.0           1.60           0.2        1
# 26    27            5.0           3.4           1.60           0.4        1
# 27    28            5.2           3.5           1.50           0.2        1
# 28    29            5.2           3.4           1.40           0.2        1
# 29    30            4.7           3.2           1.60           0.2        1
# ..   ...            ...           ...            ...           ...      ...
# 122  123            7.7           2.8           6.70           2.0        0
# 123  124            6.3           2.7           4.90           1.8        0
# 124  125            6.7           3.3           5.70           2.1        0
# 125  126            7.2           3.2           6.00           1.8        0
# 126  127            6.2           2.8           4.80           1.8        0
# 127  128            6.1           3.0           4.90           1.8        0
# 128  129            6.4           2.8           5.60           2.1        0
# 129  130            7.2           3.0           5.80           1.6        0
# 130  131            7.4           2.8           6.10           1.9        0
# 131  132            7.9           3.8           6.40           2.0        0
# 132  133            6.4           2.8           5.60           2.2        0
# 133  134            6.3           2.8           5.10           1.5        0
# 134  135            6.1           2.6           5.60           1.4        0
# 135  136            7.7           3.0           6.10           2.3        0
# 136  137            6.3           3.4           5.60           2.4        0
# 137  138            6.4           3.1           5.50           1.8        0
# 138  139            6.0           3.0           4.80           1.8        0
# 139  140            6.9           3.1           5.40           2.1        0
# 140  141            6.7           3.1           5.60           2.4        0
# 141  142            6.9           3.1           5.10           2.3        0
# 142  143            5.8           2.7           5.10           1.9        0
# 143  144            6.8           3.2           5.90           2.3        0
# 144  145            6.7           3.3           5.70           2.5        0
# 145  146            6.7           3.0           5.20           2.3        0
# 146  147            6.3           2.5           5.00           1.9        0
# 147  148            6.5           3.0           5.20           2.0        0
# 148  149            6.2           3.4           5.40           2.3        0
# 149  150            5.9           3.0           5.10           1.8        0
# 150  151            5.9           3.0           4.35           1.3        0
# 151  152            5.8           3.0           4.35           1.8        0
#
# [152 rows x 6 columns]

# %% [markdown]
# ## Question 4
#
# *Observe the association of each independent variable with target variable and drop variables from feature set having correlation in range -0.1 to 0.1 with target variable.*

# %%
Iris.columns
# Out:
# Index([u'Id', u'SepalLengthCm', u'SepalWidthCm', u'PetalLengthCm',
#        u'PetalWidthCm', u'Species'],
#       dtype='object')

# %%
corr = Iris.corr()
corr
# Out:
#                      Id  SepalLengthCm  ...  PetalWidthCm   Species
# Id             1.000000       0.702734  ...      0.890676 -0.485106
# SepalLengthCm  0.702734       1.000000  ...      0.815986 -0.319507
# SepalWidthCm  -0.392693      -0.109369  ...     -0.356510 -0.188831
# PetalLengthCm  0.872346       0.871120  ...      0.962043 -0.302167
# PetalWidthCm   0.890676       0.815986  ...      1.000000 -0.378630
# Species       -0.485106      -0.319507  ...     -0.378630  1.000000
#
# [6 rows x 6 columns]

# %%
sns.heatmap(corr,annot=True)

# %%
corr[((corr['Species']>= -0.1)==True) & ((corr['Species'] <= 0.1)==True)]
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %% [markdown]
# ## Question 5
#
# *Observe the independent variables variance and drop such variables having no variance or almost zero variance(variance < 0.1). They will be having almost no influence on the classification.*

# %%
a = Iris.iloc[:,1:5]
b = a.var().to_frame('var')
b[(b['var']<0.1)==True]
# Out:
# Empty DataFrame
# Columns: [var]
# Index: []

# %%
b.reset_index(inplace=True)

# %%
b
# Out:
#            index       var
# 0  SepalLengthCm  0.681143
# 1   SepalWidthCm  0.188004
# 2  PetalLengthCm  3.113179
# 3   PetalWidthCm  0.580926

# %% [markdown]
# ## Question 6
#
# *Plot the scatter matrix for all the variables.*

# %%
Iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        1
# 1      2            4.9           3.0            1.4           0.2        1
# 2      3            4.7           3.2            1.3           0.2        1
# 3      4            4.6           3.1            1.5           0.2        1
# 4      5            5.0           3.6            1.4           0.2        1
# 5      6            5.4           3.9            1.7           0.4        1
# 6      7            4.6           3.4            1.4           0.3        1
# 7      8            5.0           3.4            1.5           0.2        1
# 8      9            4.4           2.9            1.4           0.2        1
# 9     10            4.9           3.1            1.5           0.1        1
# 10    11            5.4           3.7            1.5           0.2        1
# 11    12            4.8           3.4            1.6           0.2        1
# 12    13            4.8           3.0            1.4           0.1        1
# 13    14            4.3           3.0            1.1           0.1        1
# 14    15            5.8           4.0            1.2           0.2        1
# 15    16            5.7           4.4            1.5           0.4        1
# 16    17            5.4           3.9            1.3           0.4        1
# 17    18            5.1           3.5            1.4           0.3        1
# 18    19            5.7           3.8            1.7           0.3        1
# 19    20            5.1           3.8            1.5           0.3        1
# 20    21            5.4           3.4            1.7           0.2        1
# 21    22            5.1           3.7            1.5           0.4        1
# 22    23            4.6           3.6            1.0           0.2        1
# 23    24            5.1           3.3            1.7           0.5        1
# 24    25            4.8           3.4            1.9           0.2        1
# 25    26            5.0           3.0            1.6           0.2        1
# 26    27            5.0           3.4            1.6           0.4        1
# 27    28            5.2           3.5            1.5           0.2        1
# 28    29            5.2           3.4            1.4           0.2        1
# 29    30            4.7           3.2            1.6           0.2        1
# ..   ...            ...           ...            ...           ...      ...
# 122  123            7.7           2.8            6.7           2.0        0
# 123  124            6.3           2.7            4.9           1.8        0
# 124  125            6.7           3.3            5.7           2.1        0
# 125  126            7.2           3.2            6.0           1.8        0
# 126  127            6.2           2.8            4.8           1.8        0
# 127  128            6.1           3.0            4.9           1.8        0
# 128  129            6.4           2.8            5.6           2.1        0
# 129  130            7.2           3.0            5.8           1.6        0
# 130  131            7.4           2.8            6.1           1.9        0
# 131  132            7.9           3.8            6.4           2.0        0
# 132  133            6.4           2.8            5.6           2.2        0
# 133  134            6.3           2.8            5.1           1.5        0
# 134  135            6.1           2.6            5.6           1.4        0
# 135  136            7.7           3.0            6.1           2.3        0
# 136  137            6.3           3.4            5.6           2.4        0
# 137  138            6.4           3.1            5.5           1.8        0
# 138  139            6.0           3.0            4.8           1.8        0
# 139  140            6.9           3.1            5.4           2.1        0
# 140  141            6.7           3.1            5.6           2.4        0
# 141  142            6.9           3.1            5.1           2.3        0
# 142  143            5.8           2.7            5.1           1.9        0
# 143  144            6.8           3.2            5.9           2.3        0
# 144  145            6.7           3.3            5.7           2.5        0
# 145  146            6.7           3.0            5.2           2.3        0
# 146  147            6.3           2.5            5.0           1.9        0
# 147  148            6.5           3.0            5.2           2.0        0
# 148  149            6.2           3.4            5.4           2.3        0
# 149  150            5.9           3.0            5.1           1.8        0
# 150  151            5.9           NaN            NaN           NaN        0
# 151  152            NaN           NaN            NaN           1.8        0
#
# [152 rows x 6 columns]

# %%
ge =sns.pairplot(Iris)
ge.fig.autofmt_xdate()
plt.show()

# %% [markdown]
# ## Split the dataset into training and test sets
#
# ## Question 7
#
# *Split the dataset into training and test sets with 80-20 ratio.*

# %%
Iris.columns
# Out:
# Index([u'Id', u'SepalLengthCm', u'SepalWidthCm', u'PetalLengthCm',
#        u'PetalWidthCm', u'Species'],
#       dtype='object')

# %%
## Creating the K Nearest Neighbour Classifier Object
## weights options are 'uniform' 'distance'
## weights = 'distance' - weighs points by inverse of their distance
NNH = KNeighborsClassifier(n_neighbors = 21, weights = 'uniform', 
                           metric = 'euclidean')

# %%
del Iris['Id']

# %%
Iris_I = Iris.iloc[:,0:4]
Iris_T = Iris.iloc[:,4:5]

# %%
from sklearn.model_selection import train_test_split
X_train,X_Test, Y_Train,Y_Test = train_test_split(Iris_I,Iris_T,test_size = 0.2)
(X_train.shape, Y_Train.shape,X_Test.shape,Y_Test.shape )
# Out:
# ((121, 4), (121, 1), (31, 4), (31, 1))

# %%
## Fit the model
## Creating the K Nearest Neighbour Classifier Object
## weights options are 'uniform' 'distance'
## weights = 'distance' - weighs points by inverse of their distance
NNH = KNeighborsClassifier(n_neighbors = 21, weights = 'uniform', 
                           metric = 'euclidean')
mod=NNH.fit(X_train, Y_Train)
predict_value = mod.predict(X_Test)

pv = pd.DataFrame(predict_value)
pv
yTest=pd.DataFrame(Y_Test)
yTest

accuracy_score(pv,yTest)
# Out:
# 1.0

# %% [markdown]
# ## Question 8 - Model
#
# *Build the model and train and test on training and test sets respectively using **scikit-learn**. Print the Accuracy of the model with different values of **k=3,5,9**.*
#
# **Hint:** For accuracy you can check **accuracy_score()** in scikit-learn

# %%
## Get the probability
Iris['prob'] = pd.DataFrame(NNH.predict_proba(X_train))[1]
Iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species  prob
# 0            5.1           3.5            1.4           0.2        1   0.0
# 1            4.9           3.0            1.4           0.2        1   0.0
# 2            4.7           3.2            1.3           0.2        1   0.0
# 3            4.6           3.1            1.5           0.2        1   1.0
# 4            5.0           3.6            1.4           0.2        1   0.0

# %%
# Compute and print AUC score
from sklearn.metrics import roc_auc_score
auc = roc_auc_score(Iris["Species"],Iris["prob"])
auc
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-323-9170b1728e6d> in <module>()
#       1 from sklearn.metrics import roc_auc_score
# ----> 2 auc = roc_auc_score(Iris["Species"],Iris["prob"])
#       3 auc
#
# /usr/local/lib/python2.7/dist-packages/sklearn/metrics/ranking.pyc in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr)
#     354     return _average_binary_score(
#     355         _binary_roc_auc_score, y_true, y_score, average,
# --> 356         sample_weight=sample_weight)
#     357
#     358
#
# /usr/local/lib/python2.7/dist-packages/sklearn/metrics/base.pyc in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      72     y_type = type_of_target(y_true)
#      73     if y_type not in ("binary", "multilabel-indicator"):
# ---> 74         raise ValueError("{0} format is not supported".format(y_type))
#      75
#      76     if y_type == "binary":
#
# ValueError: multiclass format is not supported

# %% [markdown]
# ## Question 9 - Finding Optimal value of k.
#
# Run the KNN with no of neighbours to be 1,3,5..19 and *Find the **optimal number of neighbours** from the above list using the Miss classification error

# %% [markdown]
# Hint:
#
# Misclassification error (MSE) = 1 - Test accuracy score. Calculated MSE for each model with neighbours = 1,3,5...19 and find the model with lowest MSE

# %% [markdown]
# ## Question 10
#
# *Plot misclassification error vs k (with k value on X-axis) using matplotlib.*

# %% [markdown]
# ### Question 11: Read the data given in bc2.csv file

# %% [markdown]
# ### Question 12: Observe the no.of records in dataset and type of each feature

# %% [markdown]
# ### Question 13: Use summary statistics to check if missing values, outlier and encoding treament is necessary

# %% [markdown]
# ### Check Missing Values

# %% [markdown]
# ### Question 14: Check how many `?` there in Bare Nuclei feature (they are also unknown or missing values). Replace them with the top value of the describe function of Bare Nuclei feature.
#
# #### Check include='all' parameter in describe function

# %% [markdown]
# ### Question 15: Find the distribution of target variable (Class)

# %% [markdown]
# #### Plot the distribution of target variable using histogram

# %% [markdown]
# ### convert the datatype of Bare Nuclei to `int`

# %% [markdown]
# ### Question 16: Standardization of Data

# %% [markdown]
# ### Question 17: Plot Scatter Matrix to understand the distribution of variables and check if any variables are collinear and drop one of them.

# %% [markdown]
# ### Question 18: Divide the dataset into feature set and target set

# %% [markdown]
# ### Divide the Training and Test sets in 70:30

# %% [markdown]
# ## Question 19 - Finding Optimal value of k
#
# Run the KNN with no of neighbours to be 1,3,5..19 and *Find the **optimal number of neighbours** from the above list using the Mis classification error

# %% [markdown]
# Hint:
#
# Misclassification error (MSE) = 1 - Test accuracy score. Calculated MSE for each model with neighbours = 1,3,5...19 and find the model with lowest MSE

# %% [markdown]
# ### Question 20: Print the optimal number of neighbors
